# %%
from src.agents import *

# %%
chat_result = admin.initiate_chat(
    multimodal_data_assistant,
    message="""
Extract the images and text from the html files in the html_folder
""",
)
# Out:
# admin (to multimodal_data_assistant):
#
#
# Extract the images and text from the html files in the html_folder
#
#
# --------------------------------------------------------------------------------
# multimodal_data_assistant (to admin):
#
# ***** Suggested tool call (call_BXXhApXqTbgpUto2X90jH2US): HTML_Scraper *****
# Arguments:
# {"folder":"html_folder"}
# *****************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION HTML_Scraper...
#
#         @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#         @@@@@@@@@@@@@@@@@@@&   /&@@@(   /@@@@@@@@@@@@@@@@@@@
#         @@@@@@@@@@@@@@@ %@@@@@@@@@@@@@@@@@@@ *@@@@@@@@@@@@@@
#         @@@@@@@@@@@@ @@@@@@@@@@@@@@,  .@@@@@@@@ *@@@@@@@@@@@
#         @@@@@@@@@.#@@@@@@@@@@@@@@@@,    @@@@@@@@@@ @@@@@@@@@
#         @@@@@@@&,@@@@@@@@@@@@@@@@@@.    @@@@@@@@@@@@ @@@@@@@
#         @@@@@@ @@@@@@@@@@@@@@@@@@@@     @@@@@@@@@@@@@ @@@@@@
#         @@@@@ @@@@@@@@@@@@@@@@@@@@@    *@@@@@@@@@@@@@@/@@@@@
#         @@@@ @@@@@@@@@@@@@@@@@@@@@@    @@@@@@@@@@@@@@@@,@@@@
#         @@@ @@@@@@@@@@@@@@@@@@@@@@&    @@@@@@@@@@@@@@@@@ @@@
#         @@@,@@@@@@@@@@@@@@@@@@@@@@*   (@@@@@@@@@@@@@@@@@@%@@
#         @@.@@@@@@@@@@@@@@@@@@@@@@@    @@@@@@@@@@@@@@@@@@@ @@
#         @@ @@@@@@@@@@@@@@@@@@@@@@@    @@@@@@@@@@@@@@@@@@@ @@
#         @@ @@@@@@@@@@@@@@@@@@@@@@/   &@@@@@@@@@@@@@@@@@@@ @@
#         @@,@@@@@@@@@@@@@@@@@@@@@@    @@@@@@@@@@@@@@@@@@@@ @@
#         @@@.@@@@@@@@@@@@@@@@@@@@&   @@@@@@@@@@@@@@@@@@@@@%@@
#         @@@ @@@@@@@@@@@@@@@@@@@@@  /@@@@@@@@@@@@@@@@@@@@ @@@
#         @@@@ @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@,@@@@
#         @@@@@ @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@*@@@@@
#         @@@@@@ @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ @@@@@@
#         @@@@@@@@ @@@@@@@@@@@@    @@@@@@@@@@@@@@@@@@@ @@@@@@@
#         @@@@@@@@@.(@@@@@@@@@@     @@@@@@@@@@@@@@@@ @@@@@@@@@
#         @@@@@@@@@@@@ @@@@@@@@@#   #@@@@@@@@@@@@ /@@@@@@@@@@@
#         @@@@@@@@@@@@@@@ ,@@@@@@@@@@@@@@@@@@@ &@@@@@@@@@@@@@@
#         @@@@@@@@@@@@@@@@@@@@   ,%@@&/   (@@@@@@@@@@@@@@@@@@@
#         @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Running HTML Scraper
# >>> Time Elapsed: 2.43 sec (1 articles)tml_folder\nmat2272.html
# Running Caption Distributor
# >>> Time Elapsed: 0.01 sec (0 captions)
# Running Figure Separator
# >>> Time Elapsed: 0.01 sec (0 figures)
# Matching Image Objects to Caption Text
# >>> SUCCESS! Matching objects from figure: nmat2272_fig4.jpg
# Printing Master Image Objects to: C:\Users\kvriz\Desktop\DataMiningAgents\custom_tools\external_tools\exsclaim\output\html-scraping/images
# >>> SUCCESS!
# admin (to multimodal_data_assistant):
#
# admin (to multimodal_data_assistant):
#
# ***** Response from calling tool (call_BXXhApXqTbgpUto2X90jH2US) *****
# {"nmat2272_fig1.jpg": {"title": "The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig1.jpg", "full_caption": "a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.", "figure_path": "output\\figures\\nmat2272_fig1.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig2.jpg": {"title": "The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig2.jpg", "full_caption": "a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.", "figure_path": "output\\figures\\nmat2272_fig2.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig3.jpg": {"title": "The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig3.jpg", "full_caption": "a, Molecular structure of copolymer P9. b, Spectroelectrochemistry of polymer P9 with its respective bandgap as estimated from the onset of absorption. The film was spray-cast onto ITO-coated glass from solution (4 mg ml−1) in toluene (absorption maximum=1.13 a.u.). The applied potential was increased in 25 mV steps: +0.04 V⇒+0.74 V. c, The colours of P9 obtained on electrochemical switching both in the neutral state (left) and on full oxidation (right).", "figure_path": "output\\figures\\nmat2272_fig3.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig4.jpg": {"title": "The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig4.jpg", "full_caption": "a, Relative luminance as a function of applied potential and film thickness for spray-coated P9. The legend indicates the absorbance of the deposited films (estimated at the absorption maximum) and gives an indication of the thickness obtained on spraying. For colour matching, L*a*b* values (in the sense of the Commission Internationale de l’Eclairage 1976 L*a*b* colour model) of fully neutral and oxidized states are reported for the films. b, Square-wave potential step absorptometry of P9 spray-coated on ITO and monitored at 636 nm (left) and 428 nm (right) in 0.1 M LiBF4/PC solution, −0.6 V to +0.7 V versus Fc/Fc+. Switch times (ν): 10 s step for 40 s (two cycles), 5 ...
# **********************************************************************
#
# --------------------------------------------------------------------------------
# multimodal_data_assistant (to admin):
#
# The images and text have been successfully extracted from the HTML files in the specified folder. Here are the details:
#
# 1. **Image: nmat2272_fig1.jpg**
#    - **Title:** The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials
#    - **Article Name:** nmat2272
#    - **Image URL:** [Link](https://www.nature.com/articles/nmat2272)
#    - **Figure Name:** nmat2272_fig1.jpg
#    - **Full Caption:**
#      - a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4.
#      - b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions.
#      - c, The colours obtained on polymerization of each system.
#    - **Figure Path:** output\figures\nmat2272_fig1.jpg
#
# 2. **Image: nmat2272_fig2.jpg**
#    - **Title:** The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials
#    - **Article Name:** nmat2272
#    - **Image URL:** [Link](https://www.nature.com/articles/nmat2272)
#    - **Figure Name:** nmat2272_fig2.jpg
#    - **Full Caption:**
#      - a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8.
#      - b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions.
#      - c, The colours obtained on polymerization of each system.
#    - **Figure Path:** output\figures\nmat2272_fig2.jpg
#
# 3. **Image: nmat2272_fig3.jpg**
#    - **Title:** The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials
#    - **Article Name:** nmat2272
#    - **Image URL:** [Link](https://www.nature.com/articles/nmat2272)
#    - **Figure Name:** nmat2272_fig3.jpg
#    - **Full Caption:**
#      - a, Molecular structure of copolymer P9.
#      - b, Spectroelectrochemistry of polymer P9 with its respective bandgap as estimated from the onset of absorption. The film was spray-cast onto ITO-coated glass from solution (4 mg ml−1) in toluene (absorption maximum=1.13 a.u.). The applied potential was increased in 25 mV steps: +0.04 V⇒+0.74 V.
#      - c, The colours of P9 obtained on electrochemical switching both in the neutral state (left) and on full oxidation (right).
#    - **Figure Path:** output\figures\nmat2272_fig3.jpg
#
# 4. **Image: nmat2272_fig4.jpg**
#    - **Title:** The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials
#    - **Article Name:** nmat2272
#    - **Image URL:** [Link](https://www.nature.com/articles/nmat2272)
#    - **Figure Name:** nmat2272_fig4.jpg
#    - **Full Caption:**
#      - a, Relative luminance as a function of applied potential and film thickness for spray-coated P9. The legend indicates the absorbance of the deposited films (estimated at the absorption maximum) and gives an indication of the thickness obtained on spraying. For colour matching, L*a*b* values (in the sense of the Commission Internationale de l’Eclairage 1976 L*a*b* colour model) of fully neutral and oxidized states are reported for the films.
#      - b, Square-wave potential step absorptometry of P9 spray-coated on ITO and monitored at 636 nm (left) and 428 nm (right) in 0.1 M LiBF4/PC solution, −0.6 V to +0.7 V versus Fc/Fc+. Switch times (ν): 10 s step for 40 s (two cycles), 5 s step for 30 s (three cycles), 2 s step for 20 s (five cycles), then 1.75 s step for 20 s and 1.5 s step for 20 s from left to right.
#    - **Figure Path:** output\figures\nmat2272_fig4.jpg
#
# If you need further assistance or specific details, feel free to ask!
#
# --------------------------------------------------------------------------------
# admin (to multimodal_data_assistant):
#
# TERMINATE
#
# --------------------------------------------------------------------------------

# %%
chat_result
# Out:
# ChatResult(chat_id=None, chat_history=[{'content': '\nExtract the images and text from the html files in the html_folder\n', 'role': 'assistant', 'name': 'admin'}, {'tool_calls': [{'id': 'call_BXXhApXqTbgpUto2X90jH2US', 'function': {'arguments': '{"folder":"html_folder"}', 'name': 'HTML_Scraper'}, 'type': 'function'}], 'content': None, 'role': 'assistant'}, {'content': '{"nmat2272_fig1.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig1.jpg", "full_caption": "a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.", "figure_path": "output\\\\figures\\\\nmat2272_fig1.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig2.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig2.jpg", "full_caption": "a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.", "figure_path": "output\\\\figures\\\\nmat2272_fig2.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig3.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig3.jpg", "full_caption": "a, Molecular structure of copolymer P9. b, Spectroelectrochemistry of polymer P9 with its respective bandgap as estimated from the onset of absorption. The film was spray-cast onto ITO-coated glass from solution (4\u2009mg\u2009ml−1) in toluene (absorption maximum=1.13\u2009a.u.). The applied potential was increased in 25\u2009mV steps: +0.04\u2009V⇒+0.74\u2009V. c, The colours of P9 obtained on electrochemical switching both in the neutral state (left) and on full oxidation (right).", "figure_path": "output\\\\figures\\\\nmat2272_fig3.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig4.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig4.jpg", "full_caption": "a,\xa0Relative luminance as a function of applied potential and film thickness for spray-coated P9. The legend indicates the absorbance of the deposited films (estimated at the absorption maximum) and gives an indication of the thickness obtained on  ...

# %%
chat_result.chat_history
# Out:
# [{'content': '\nExtract the images and text from the html files in the html_folder\n',
#   'role': 'assistant',
#   'name': 'admin'},
#  {'tool_calls': [{'id': 'call_dX5eYvpXGzSBZOQdEiM5F4Um',
#     'function': {'arguments': '{"folder":"html_folder"}',
#      'name': 'HTML_Scraper'},
#     'type': 'function'}],
#   'content': None,
#   'role': 'assistant'},
#  {'content': '{"nmat2272_fig1.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig1.jpg", "full_caption": "a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.", "figure_path": "output\\\\figures\\\\nmat2272_fig1.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig2.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig2.jpg", "full_caption": "a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.", "figure_path": "output\\\\figures\\\\nmat2272_fig2.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig3.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig3.jpg", "full_caption": "a, Molecular structure of copolymer P9. b, Spectroelectrochemistry of polymer P9 with its respective bandgap as estimated from the onset of absorption. The film was spray-cast onto ITO-coated glass from solution (4\u2009mg\u2009ml−1) in toluene (absorption maximum=1.13\u2009a.u.). The applied potential was increased in 25\u2009mV steps: +0.04\u2009V⇒+0.74\u2009V. c, The colours of P9 obtained on electrochemical switching both in the neutral state (left) and on full oxidation (right).", "figure_path": "output\\\\figures\\\\nmat2272_fig3.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig4.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig4.jpg", "full_caption": "a,\xa0Relative luminance as a function of applied potential and film thickness for spray-coated P9. The legend indicates the absorbance of the deposited films (estimated at the absorption maximum) and gives an indication of the thickness obtained on spraying. For colour matching, L*a*b* values (in the sense of the Commission Internationale de l’Eclairage 1976 L*a*b* colour model) of fully neutral and oxidized states are reported for the films. b,\xa0Square-wave potential step absorptometry of P9 spray-coated on ITO and monitored at 636\u2009nm (left) and 428\u2009nm (right) in 0.1\u2009M LiBF4/PC solut ...
#   'tool_responses': [{'tool_call_id': 'call_dX5eYvpXGzSBZOQdEiM5F4Um',
#     'role': 'tool',
#     'content': '{"nmat2272_fig1.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig1.jpg", "full_caption": "a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.", "figure_path": "output\\\\figures\\\\nmat2272_fig1.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig2.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig2.jpg", "full_caption": "a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.", "figure_path": "output\\\\figures\\\\nmat2272_fig2.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig3.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig3.jpg", "full_caption": "a, Molecular structure of copolymer P9. b, Spectroelectrochemistry of polymer P9 with its respective bandgap as estimated from the onset of absorption. The film was spray-cast onto ITO-coated glass from solution (4\u2009mg\u2009ml−1) in toluene (absorption maximum=1.13\u2009a.u.). The applied potential was increased in 25\u2009mV steps: +0.04\u2009V⇒+0.74\u2009V. c, The colours of P9 obtained on electrochemical switching both in the neutral state (left) and on full oxidation (right).", "figure_path": "output\\\\figures\\\\nmat2272_fig3.jpg", "master_images": [], "article_url": [], "license": [], "open": [], "unassigned": {"master_images": [], "dependent_images": [], "inset_images": [], "subfigure_labels": [], "scale_bar_labels": [], "scale_bar_lines": [], "captions": []}}, "nmat2272_fig4.jpg": {"title": "The donor–acceptor approach allows a\xa0black-to-transmissive switching polymeric electrochrome | Nature Materials", "article_name": "nmat2272", "image_url": "https://www.nature.com/articles/nmat2272", "figure_name": "nmat2272_fig4.jpg", "full_caption": "a,\xa0Relative luminance as a function of applied potential and film thickness for spray-coated P9. The legend indicates the absorbance of the deposited films (estimated at the absorption maximum) and gives an indication of the thickness obtained on spraying. For colour matching, L*a*b* values (in the sense of the Commission Internationale de l’Eclairage 1976 L*a*b* colour model) of fully neutral and oxidized states are reported for the films. b,\xa0Square-wave potential step absorptometry of P9 spray-coated on ITO and monitored at 636\u2009nm (left) and 428\u2009nm (right) in 0.1\u2009M LiBF4/PC sol ...
#   'role': 'tool',
#   'name': 'admin'},
#  {'content': 'I have extracted the images and text from the HTML files in the specified folder. Here are the details:\n\n1. **Figure: nmat2272_fig1.jpg**\n   - **Title:** The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials\n   - **Article Name:** nmat2272\n   - **Image URL:** [Link](https://www.nature.com/articles/nmat2272)\n   - **Full Caption:** \n     - a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4.\n     - b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions.\n     - c, The colours obtained on polymerization of each system.\n   - **Figure Path:** output\\figures\\nmat2272_fig1.jpg\n\n2. **Figure: nmat2272_fig2.jpg**\n   - **Title:** The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials\n   - **Article Name:** nmat2272\n   - **Image URL:** [Link](https://www.nature.com/articles/nmat2272)\n   - **Full Caption:** \n     - a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8.\n     - b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions.\n     - c, The colours obtained on polymerization of each system.\n   - **Figure Path:** output\\figures\\nmat2272_fig2.jpg\n\n3. **Figure: nmat2272_fig3.jpg**\n   - **Title:** The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials\n   - **Article Name:** nmat2272\n   - **Image URL:** [Link](https://www.nature.com/articles/nmat2272)\n   - **Full Caption:** \n     - a, Molecular structure of copolymer P9.\n     - b, Spectroelectrochemistry of polymer P9 with its respective bandgap as estimated from the onset of absorption. The film was spray-cast onto ITO-coated glass from solution (4\u2009mg\u2009ml−1) in toluene (absorption maximum=1.13\u2009a.u.). The applied potential was increased in 25\u2009mV steps: +0.04\u2009V⇒+0.74\u2009V.\n     - c, The colours of P9 obtained on electrochemical switching both in the neutral state (left) and on full oxidation (right).\n   - **Figure Path:** output\\figures\\nmat2272_fig3.jpg\n\n4. **Figure: nmat2272_fig4.jpg**\n   - **Title:** The donor–acceptor approach allows a black-to-transmissive switching polymeric electrochrome | Nature Materials\n   - **Article Name:** nmat2272\n   - **Image URL:** [Link](https://www.nature.com/articles/nmat2272)\n   - **Full Caption:** \n     - a, Relative luminance as a function of applied potential and film thickness for spray-coated P9. The legend indicates the absorbance of the deposited films (estimated at the absorption maximum) and gives an indication of the thickness obtained on spraying. For colour matching, L*a*b* values (in the sense of the Commission Internationale de l’Eclairage 1976 L*a*b* colour model) of fully neutral and oxidized states are reported for the films.\n     - b, Square-wave potential step absorptometry of P9 spray-coated on ITO and monitored at 636\u2009nm (left) and 428\u2009nm (right) in 0.1\u2009M LiBF4/PC solution, −0.6\u2009V to +0.7\u2009V versus Fc/Fc+. Switch times (ν): 10\u2009s step for 40\u2009s (two cycles), 5\u2009s step for 30\u2009s (three cycles), 2\u2009s step for 20\u2009s (five cycles), then 1.75\u2009s step for 20\u2009s and 1.5\u2009s step for 20\u2009s from left to right.\n   - **Figure Path:** output\\figures\\nmat2272_fig4.jpg\n\nIf you need further assistance, feel free to ask! Otherwise, the task is complete. TERMINATE',
#   'role': 'user',
#   'name': 'multimodal_data_assistant'}]

# %%
from src.agents import *
chat_result = admin.initiate_chat(
    multimodal_data_assistant,
    message="""
Extract the multimodal data from the html-scraping folder and classify the images based on the image and caption
""",
)
# Out:
# admin (to multimodal_data_assistant):
#
#
# Extract the multimodal data from the html-scraping folder
#
#
# --------------------------------------------------------------------------------
# multimodal_data_assistant (to admin):
#
# ***** Suggested tool call (call_C2JGuQ22X5QfPXskuGwyW5bf): image-text-retriever *****
# Arguments:
# {"exsclaim_output_folder":"html-scraping"}
# *************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION image-text-retriever...
# admin (to multimodal_data_assistant):
#
# admin (to multimodal_data_assistant):
#
# ***** Response from calling tool (call_C2JGuQ22X5QfPXskuGwyW5bf) *****
# {"records":[{"full_caption":"a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions","caption_summary":["Polymers","Absorbance Spectra","Toluene"],"image":"multimodal_data_folder\\images_folder\\nmat2272_fig1_b.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"The colours obtained on polymerization of each system","caption_summary":["Polymerization","Color","Materials"],"image":"multimodal_data_folder\\images_folder\\nmat2272_fig1_c.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4","caption_summary":["Molecular structure","Polymers","Characterization"],"image":"multimodal_data_folder\\images_folder\\nmat2272_fig1_a.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"The colours obtained on polymerization of each system","caption_summary":["Polymerization","Color","Materials"],"image":"multimodal_data_folder\\images_folder\\nmat2272_fig2_c.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions","caption_summary":["Polymers","Absorbance Spectra","Toluene"],"image":"multimodal_data_folder\\images_folder\\nmat2272_fig2_b.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7  ...
# **********************************************************************
#
# --------------------------------------------------------------------------------
# multimodal_data_assistant (to admin):
#
# The multimodal data extracted from the "html-scraping" folder includes images and their corresponding captions from the article "nmat2272". Here are the details:
#
# 1. **Image**: ![nmat2272_fig1_b.jpg](multimodal_data_folder\images_folder\nmat2272_fig1_b.jpg)
#    - **Caption**: Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions.
#    - **Summary**: Polymers, Absorbance Spectra, Toluene
#
# 2. **Image**: ![nmat2272_fig1_c.jpg](multimodal_data_folder\images_folder\nmat2272_fig1_c.jpg)
#    - **Caption**: The colours obtained on polymerization of each system
#    - **Summary**: Polymerization, Color, Materials
#
# 3. **Image**: ![nmat2272_fig1_a.jpg](multimodal_data_folder\images_folder\nmat2272_fig1_a.jpg)
#    - **Caption**: Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4
#    - **Summary**: Molecular structure, Polymers, Characterization
#
# 4. **Image**: ![nmat2272_fig2_c.jpg](multimodal_data_folder\images_folder\nmat2272_fig2_c.jpg)
#    - **Caption**: The colours obtained on polymerization of each system
#    - **Summary**: Polymerization, Color, Materials
#
# 5. **Image**: ![nmat2272_fig2_b.jpg](multimodal_data_folder\images_folder\nmat2272_fig2_b.jpg)
#    - **Caption**: Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions.
#    - **Summary**: Polymers, Absorbance Spectra, Toluene
#
# 6. **Image**: ![nmat2272_fig2_a.jpg](multimodal_data_folder\images_folder\nmat2272_fig2_a.jpg)
#    - **Caption**: Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8
#    - **Summary**: Molecular structure, Polymers, Characterization
#
# 7. **Image**: ![nmat2272_fig3_b.jpg](multimodal_data_folder\images_folder\nmat2272_fig3_b.jpg)
#    - **Caption**: Spectroelectrochemistry of polymer P9 with its respective bandgap as estimated from the onset of absorption. The film was spray-cast onto ITO-coated glass from solution (4 mg ml-1) in toluene (absorption maximum=1.13 a.u.). The applied potential was increased in 25 mV steps: +0.04 V⇒+0.74 V.
#    - **Summary**: Spectroelectrochemistry, Polymer P9, Bandgap
#
# 8. **Image**: ![nmat2272_fig3_a.jpg](multimodal_data_folder\images_folder\nmat2272_fig3_a.jpg)
#    - **Caption**: Molecular structure of copolymer P9
#    - **Summary**: Copolymer, Molecular Structure, Characterization
#
# 9. **Image**: ![nmat2272_fig3_c.jpg](multimodal_data_folder\images_folder\nmat2272_fig3_c.jpg)
#    - **Caption**: The colours of P9 obtained on electrochemical switching both in the neutral state (left) and on full oxidation (right)
#    - **Summary**: electrochromic materials, color switching, P9
#
# 10. **Image**: ![nmat2272_fig4_c.jpg](multimodal_data_folder\images_folder\nmat2272_fig4_c.jpg)
#     - **Caption**: []
#     - **Summary**: []
#
# 11. **Image**: ![nmat2272_fig4_b.jpg](multimodal_data_folder\images_folder\nmat2272_fig4_b.jpg)
#     - **Caption**: Square-wave potential step absorptometry of P9 spray-coated on ITO and monitored at 636 nm (left) and 428 nm (right) in 0.1 M LiBF4/PC solution, -0.6 V to +0.7 V versus Fc/Fc+. Switch times (ν): 10 s step for 40 s (two cycles), 5 s step for 30 s (three cycles), 2 s step for 20 s (five cycles), then 1.75 s step for 20 s and 1.5 s step for 20 s from left to right.
#     - **Summary**: Square-wave potential step absorptometry, P9 spray-coated, LiBF4/PC solution
#
# 12. **Image**: ![nmat2272_fig4_a.jpg](multimodal_data_folder\images_folder\nmat2272_fig4_a.jpg)
#     - **Caption**: Relative luminance as a function of applied potential and film thickness for spray-coated P9. The legend indicates the absorbance of the deposited films (estimated at the absorption maximum) and gives an indication of the thickness obtained on spraying. For colour matching, L*a*b* values (in the sense of the Commission Internationale de l’Eclairage 1976 L*a*b* colour model) of fully neutral and oxidized states are reported for the films.
#     - **Summary**: spray-coating, thin films, color matching
#
# If you need further assistance, feel free to ask! TERMINATE
#
# --------------------------------------------------------------------------------

# %%
chat_result.chat_history
# Out:
# [{'content': '\nExtract the multimodal data from the html-scraping folder\n',
#   'role': 'assistant',
#   'name': 'admin'},
#  {'tool_calls': [{'id': 'call_C2JGuQ22X5QfPXskuGwyW5bf',
#     'function': {'arguments': '{"exsclaim_output_folder":"html-scraping"}',
#      'name': 'image-text-retriever'},
#     'type': 'function'}],
#   'content': None,
#   'role': 'assistant'},
#  {'content': '{"records":[{"full_caption":"a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions","caption_summary":["Polymers","Absorbance Spectra","Toluene"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig1_b.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"The colours obtained on polymerization of each system","caption_summary":["Polymerization","Color","Materials"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig1_c.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4","caption_summary":["Molecular structure","Polymers","Characterization"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig1_a.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"The colours obtained on polymerization of each system","caption_summary":["Polymerization","Color","Materials"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig2_c.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions","caption_summary":["Polymers","Absorbance Spectra","Toluene"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig2_b.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorban ...
#   'tool_responses': [{'tool_call_id': 'call_C2JGuQ22X5QfPXskuGwyW5bf',
#     'role': 'tool',
#     'content': '{"records":[{"full_caption":"a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions","caption_summary":["Polymers","Absorbance Spectra","Toluene"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig1_b.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"The colours obtained on polymerization of each system","caption_summary":["Polymerization","Color","Materials"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig1_c.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4. b, Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4","caption_summary":["Molecular structure","Polymers","Characterization"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig1_a.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"The colours obtained on polymerization of each system","caption_summary":["Polymerization","Color","Materials"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig2_c.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions. c, The colours obtained on polymerization of each system.","caption":"Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions","caption_summary":["Polymers","Absorbance Spectra","Toluene"],"image":"multimodal_data_folder\\\\images_folder\\\\nmat2272_fig2_b.jpg","article_name":"nmat2272"},{"full_caption":"a, Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8. b, Solution optical absorb ...
#   'role': 'tool',
#   'name': 'admin'},
#  {'content': 'The multimodal data extracted from the "html-scraping" folder includes images and their corresponding captions from the article "nmat2272". Here are the details:\n\n1. **Image**: ![nmat2272_fig1_b.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig1_b.jpg)\n   - **Caption**: Solution optical absorbance spectra of polymers P1, P2, P3 and control polymer P4 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions.\n   - **Summary**: Polymers, Absorbance Spectra, Toluene\n\n2. **Image**: ![nmat2272_fig1_c.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig1_c.jpg)\n   - **Caption**: The colours obtained on polymerization of each system\n   - **Summary**: Polymerization, Color, Materials\n\n3. **Image**: ![nmat2272_fig1_a.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig1_a.jpg)\n   - **Caption**: Molecular structure of M1, M2, M3, M4, P1, P2, P3 and control polymer P4\n   - **Summary**: Molecular structure, Polymers, Characterization\n\n4. **Image**: ![nmat2272_fig2_c.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig2_c.jpg)\n   - **Caption**: The colours obtained on polymerization of each system\n   - **Summary**: Polymerization, Color, Materials\n\n5. **Image**: ![nmat2272_fig2_b.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig2_b.jpg)\n   - **Caption**: Solution optical absorbance spectra of polymers P5, P6, P7 and control polymer P8 in toluene (spectrum of each system is normalized at the longer wavelength absorption maximum). The legend specifies the values of the respective absorption maxima for both high- and low-energy transitions.\n   - **Summary**: Polymers, Absorbance Spectra, Toluene\n\n6. **Image**: ![nmat2272_fig2_a.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig2_a.jpg)\n   - **Caption**: Molecular structure of M5, M6, M7, M8, P5, P6, P7 and control polymer P8\n   - **Summary**: Molecular structure, Polymers, Characterization\n\n7. **Image**: ![nmat2272_fig3_b.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig3_b.jpg)\n   - **Caption**: Spectroelectrochemistry of polymer P9 with its respective bandgap as estimated from the onset of absorption. The film was spray-cast onto ITO-coated glass from solution (4 mg ml-1) in toluene (absorption maximum=1.13 a.u.). The applied potential was increased in 25 mV steps: +0.04 V⇒+0.74 V.\n   - **Summary**: Spectroelectrochemistry, Polymer P9, Bandgap\n\n8. **Image**: ![nmat2272_fig3_a.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig3_a.jpg)\n   - **Caption**: Molecular structure of copolymer P9\n   - **Summary**: Copolymer, Molecular Structure, Characterization\n\n9. **Image**: ![nmat2272_fig3_c.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig3_c.jpg)\n   - **Caption**: The colours of P9 obtained on electrochemical switching both in the neutral state (left) and on full oxidation (right)\n   - **Summary**: electrochromic materials, color switching, P9\n\n10. **Image**: ![nmat2272_fig4_c.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig4_c.jpg)\n    - **Caption**: []\n    - **Summary**: []\n\n11. **Image**: ![nmat2272_fig4_b.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig4_b.jpg)\n    - **Caption**: Square-wave potential step absorptometry of P9 spray-coated on ITO and monitored at 636 nm (left) and 428 nm (right) in 0.1 M LiBF4/PC solution, -0.6 V to +0.7 V versus Fc/Fc+. Switch times (ν): 10 s step for 40 s (two cycles), 5 s step for 30 s (three cycles), 2 s step for 20 s (five cycles), then 1.75 s step for 20 s and 1.5 s step for 20 s from left to right.\n    - **Summary**: Square-wave potential step absorptometry, P9 spray-coated, LiBF4/PC solution\n\n12. **Image**: ![nmat2272_fig4_a.jpg](multimodal_data_folder\\images_folder\\nmat2272_fig4_a.jpg)\n    - **Caption**: Relative luminance as a function of applied potential and film thickness  ...
#   'role': 'user',
#   'name': 'multimodal_data_assistant'}]

# %%
from src.agents import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.agents import *
#
# File c:\Users\kvriz\Desktop\DataMiningAgents\src\agents.py:208
#     205 _clear_history_glob()
#     207 # Multimodal Agent
# --> 208 multi_modal_agent = MultimodalConversableAgent(
#     209     name="multi_modal_agent",
#     210     system_message='''multi_modal_agent.
#     211     You extract important information from a plot.
#     212     ''',
#     213     llm_config={"config_list": gpt4o_config, "temperature": 0.0},
#     214     description="Extract important information from the plots."
#     215 )
#     217 # Function for Classifying Figures
#     218 @admin_core.register_for_execution()
#     219 @planner.register_for_llm(description='''Use this function to assign tags to images.
#     220 This function processes records generated by the previous agent.''')
#     221 def classify_figures(records: Annotated[list, "List of dictionaries with 'image' and 'caption' keys"]) -> str:
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\agentchat\contrib\multimodal_conversable_agent.py:45, in MultimodalConversableAgent.__init__(self, name, system_message, is_termination_msg, *args, **kwargs)
#      29 def __init__(
#      30     self,
#      31     name: str,
#    (...)
#      35     **kwargs,
#      36 ):
#      37     """
#      38     Args:
#      39         name (str): agent name.
#    (...)
#      43             [ConversableAgent](../conversable_agent#__init__).
#      44     """
# ---> 45     super().__init__(
#      46         name,
#      47         system_message,
#      48         is_termination_msg=is_termination_msg,
#      49         *args,
#      50         **kwargs,
#      51     )
#      52     # call the setter to handle special format.
#      53     self.update_system_message(system_message)
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\agentchat\conversable_agent.py:170, in ConversableAgent.__init__(self, name, system_message, is_termination_msg, max_consecutive_auto_reply, human_input_mode, function_map, code_execution_config, llm_config, default_auto_reply, description, chat_messages, silent)
#     164     except TypeError as e:
#     165         raise TypeError(
#     166             "Please implement __deepcopy__ method for each value class in llm_config to support deepcopy."
#     167             " Refer to the docs for more details: https://ag2ai.github.io/autogen/docs/topics/llm_configuration#adding-http-client-in-llm_config-for-proxy"
#     168         ) from e
# --> 170 self._validate_llm_config(llm_config)
#     172 if logging_enabled():
#     173     log_new_agent(self, locals())
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\agentchat\conversable_agent.py:274, in ConversableAgent._validate_llm_config(self, llm_config)
#     270 if self.llm_config in [{}, {"config_list": []}, {"config_list": [{"model": ""}]}]:
#     271     raise ValueError(
#     272         "When using OpenAI or Azure OpenAI endpoints, specify a non-empty 'model' either in 'llm_config' or in each config of 'config_list'."
#     273     )
# --> 274 self.client = None if self.llm_config is False else OpenAIWrapper(**self.llm_config)
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\oai\client.py:501, in OpenAIWrapper.__init__(self, config_list, **base_config)
#     498 self._config_list: List[Dict[str, Any]] = []
#     500 if config_list:
# --> 501     config_list = [config.copy() for config in config_list]  # make a copy before modifying
#     502     for config in config_list:
#     503         self._register_default_client(config, openai_config)  # could modify the config
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\oai\client.py:501, in <listcomp>(.0)
#     498 self._config_list: List[Dict[str, Any]] = []
#     500 if config_list:
# --> 501     config_list = [config.copy() for config in config_list]  # make a copy before modifying
#     502     for config in config_list:
#     503         self._register_default_client(config, openai_config)  # could modify the config
#
# AttributeError: 'str' object has no attribute 'copy'

# %%
chat_result = manager.initiate_chat(
    admin_core,
    message="""
Extract the multimodal data from the html-scraping folder and classify the images based on the image and caption
""",
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.agents import *
#       2 chat_result = manager.initiate_chat(
#       3     admin_core,
#       4     message="""
#       5 Extract the multimodal data from the html-scraping folder and classify the images based on the image and caption
#       6 """,
#       7 )
#
# File c:\Users\kvriz\Desktop\DataMiningAgents\src\agents.py:72
#      67 multimodal_data_assistant.register_for_llm(name="image-text-retriever", description="Calling the multimodal data retriever tool to extract image and text from the json file created from the literature scrapping. The folder containing the data is the 'html-scraping'")(multimodal_data_retriever_tool)
#      70 ## Image-related agents
#      71 # Image classification agent
# ---> 72 multi_modal_agent = MultimodalConversableAgent(name="multi_modal_agent",
#      73                   system_message='''multi_modal_agent.
#      74                   You extract important information from a scientific image.
#      75                   ''',
#      76                   llm_config={"config_list": gpt4o_config, "temperature": 0.0},
#      77                   description='Classify the images.')
#      79 # Image quality agent
#      80
#      81 # Abs image segmentation agent
#    (...)
#      84
#      85 ## Text-related agents
#      86 assistant = RetrieveAssistantAgent(
#      87     name="assistant",
#      88     system_message="assistant. You are a helpful assistant. You retrieve knowledge from a text. You should pay attention to all the details, specially quantitative data.",
#      89     llm_config=gpt4o_config,
#      90 )
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\agentchat\contrib\multimodal_conversable_agent.py:45, in MultimodalConversableAgent.__init__(self, name, system_message, is_termination_msg, *args, **kwargs)
#      29 def __init__(
#      30     self,
#      31     name: str,
#    (...)
#      35     **kwargs,
#      36 ):
#      37     """
#      38     Args:
#      39         name (str): agent name.
#    (...)
#      43             [ConversableAgent](../conversable_agent#__init__).
#      44     """
# ---> 45     super().__init__(
#      46         name,
#      47         system_message,
#      48         is_termination_msg=is_termination_msg,
#      49         *args,
#      50         **kwargs,
#      51     )
#      52     # call the setter to handle special format.
#      53     self.update_system_message(system_message)
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\agentchat\conversable_agent.py:170, in ConversableAgent.__init__(self, name, system_message, is_termination_msg, max_consecutive_auto_reply, human_input_mode, function_map, code_execution_config, llm_config, default_auto_reply, description, chat_messages, silent)
#     164     except TypeError as e:
#     165         raise TypeError(
#     166             "Please implement __deepcopy__ method for each value class in llm_config to support deepcopy."
#     167             " Refer to the docs for more details: https://ag2ai.github.io/autogen/docs/topics/llm_configuration#adding-http-client-in-llm_config-for-proxy"
#     168         ) from e
# --> 170 self._validate_llm_config(llm_config)
#     172 if logging_enabled():
#     173     log_new_agent(self, locals())
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\agentchat\conversable_agent.py:274, in ConversableAgent._validate_llm_config(self, llm_config)
#     270 if self.llm_config in [{}, {"config_list": []}, {"config_list": [{"model": ""}]}]:
#     271     raise ValueError(
#     272         "When using OpenAI or Azure OpenAI endpoints, specify a non-empty 'model' either in 'llm_config' or in each config of 'config_list'."
#     273     )
# --> 274 self.client = None if self.llm_config is False else OpenAIWrapper(**self.llm_config)
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\oai\client.py:501, in OpenAIWrapper.__init__(self, config_list, **base_config)
#     498 self._config_list: List[Dict[str, Any]] = []
#     500 if config_list:
# --> 501     config_list = [config.copy() for config in config_list]  # make a copy before modifying
#     502     for config in config_list:
#     503         self._register_default_client(config, openai_config)  # could modify the config
#
# File c:\Users\kvriz\miniconda3\envs\autogen\Lib\site-packages\autogen\oai\client.py:501, in <listcomp>(.0)
#     498 self._config_list: List[Dict[str, Any]] = []
#     500 if config_list:
# --> 501     config_list = [config.copy() for config in config_list]  # make a copy before modifying
#     502     for config in config_list:
#     503         self._register_default_client(config, openai_config)  # could modify the config
#
# AttributeError: 'str' object has no attribute 'copy'
